# %%
import pandas as pd
import numpy as np
#import pandas as pd
#import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
data=pd.read_csv(r"C:\Users\91957\Downloads\soil_quality_10000.csv")
data.head()
# Out:
#     N   P   K    ph  moisture  organic_carbon soil_quality
# 0  61   8  14  4.72        29            0.35          Bad
# 1  24  36  54  5.60        57            0.62          Bad
# 2  81  37  59  7.47        51            0.93         Good
# 3  70  53  32  8.19        16            0.47          Bad
# 4  30  30  42  4.62        24            0.51          Bad

# %%
#feature selection
x=data.iloc[: , : -1]
y=data['soil_quality']

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45, test_size=0.2)

# %%
x_train.count()
# Out:
# N                 8000
# P                 8000
# K                 8000
# ph                8000
# moisture          8000
# organic_carbon    8000
# dtype: int64

# %%
x
# Out:
#        N   P   K    ph  moisture  organic_carbon
# 0     61   8  14  4.72        29            0.35
# 1     24  36  54  5.60        57            0.62
# 2     81  37  59  7.47        51            0.93
# 3     70  53  32  8.19        16            0.47
# 4     30  30  42  4.62        24            0.51
# ...   ..  ..  ..   ...       ...             ...
# 9995  32  28  50  5.20        40            0.37
# 9996  77  23  33  5.80        30            0.53
# 9997  23  21  39  7.33        68            1.03
# 9998  72  47  57  8.40        67            1.06
# 9999  74  53  24  5.87        14            0.57
#
# [10000 rows x 6 columns]

# %%
y
# Out:
# 0        Bad
# 1        Bad
# 2       Good
# 3        Bad
# 4        Bad
#         ...
# 9995     Bad
# 9996     Bad
# 9997     Bad
# 9998     Bad
# 9999     Bad
# Name: soil_quality, Length: 10000, dtype: object

# %%
x_test.count()
# Out:
# N                 2000
# P                 2000
# K                 2000
# ph                2000
# moisture          2000
# organic_carbon    2000
# dtype: int64

# %%
data.count()
# Out:
# N                 10000
# P                 10000
# K                 10000
# ph                10000
# moisture          10000
# organic_carbon    10000
# soil_quality      10000
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline=Pipeline([
    ('scalar',StandardScaler()),
    ('model',RandomForestClassifier(n_estimators=100,random_state=42))
])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('model', RandomForestClassifier(random_state=42))])

# %%
pipeline.score(x_test,y_test)
# Out:
# 0.9995

# %%
pipeline.score(x_train,y_train)
# Out:
# 1.0

# %%
input_data=[[96,85,76,6.5,12,6.8]]

# %%
pipeline.predict(input_data)
# Out:
# C:\Users\91957\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['Bad'], dtype=object)

# %%
import joblib

# %%
joblib.dump(pipeline,"soil.pkl")
# Out:
# ['soil.pkl']

# %%
y_train
# Out:
# 4643    Bad
# 2390    Bad
# 6162    Bad
# 8678    Bad
# 6944    Bad
#        ...
# 8772    Bad
# 163     Bad
# 6012    Bad
# 6558    Bad
# 7115    Bad
# Name: soil_quality, Length: 8000, dtype: object
